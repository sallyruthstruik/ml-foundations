# %% [markdown]
# # Регрессия

# %% [markdown]
# I'd like to install open-source tools:
#
# * pandas - alternative for SFrame. I now, sframe is open-source, but pandas is more popular I think.
# * numpy - library for operationg with arrays and matrices
# * seaboarn - tool for plotting (includes matplotlib)
# * sklearn - set of machine learning algorythms

# %%
# !pip install pandas numpy seaborn sklearn

# set inline graphs
# %matplotlib notebook
# Out:
# Requirement already satisfied: pandas in /home/stas/envs/ml/lib/python2.7/site-packages
# Requirement already satisfied: numpy in /home/stas/envs/ml/lib/python2.7/site-packages
# Requirement already satisfied: seaborn in /home/stas/envs/ml/lib/python2.7/site-packages
# Requirement already satisfied: sklearn in /home/stas/envs/ml/lib/python2.7/site-packages
# Requirement already satisfied: pytz>=2011k in /home/stas/envs/ml/lib/python2.7/site-packages (from pandas)
# Requirement already satisfied: python-dateutil in /home/stas/envs/ml/lib/python2.7/site-packages (from pandas)
# Requirement already satisfied: scipy in /home/stas/envs/ml/lib/python2.7/site-packages (from seaborn)
# Requirement already satisfied: matplotlib in /home/stas/envs/ml/lib/python2.7/site-packages (from seaborn)
# Requirement already satisfied: scikit-learn in /home/stas/envs/ml/lib/python2.7/site-packages (from sklearn)
# Requirement already satisfied: six>=1.5 in /home/stas/envs/ml/lib/python2.7/site-packages (from python-dateutil->pandas)
# Requirement already satisfied: subprocess32 in /home/stas/envs/ml/lib/python2.7/site-packages (from matplotlib->seaborn)
# Requirement already satisfied: cycler>=0.10 in /home/stas/envs/ml/lib/python2.7/site-packages (from matplotlib->seaborn)
# Requirement already satisfied: functools32 in /home/stas/envs/ml/lib/python2.7/site-packages (from matplotlib->seaborn)
# Requirement already satisfied: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=1.5.6 in /home/stas/envs/ml/lib/python2.7/site-packages (from matplotlib->seaborn)

# %%
import sframe
import pandas as pd

# %%
#You can get data here https://yadi.sk/d/-4iDlOwg3HfuGv

sf = sframe.SFrame("home_data.gl/")
# Out:
# [INFO] sframe.cython.cy_server: SFrame v2.1 started. Logging /tmp/sframe_server_1493922399.log

# %% [markdown]
# ## First, convert to pandas DataFrame

# %%
df = sf.to_dataframe()

#cast to numeric values
for c in "bedrooms,bathrooms,floors,zipcode".split(","):
    df[c] = df[c].astype(float)

# show df data
print df.head()
# Out:
#            id                       date   price  bedrooms  bathrooms  \
# 0  7129300520  2014-10-13 00:00:00+00:00  221900       3.0       1.00
# 1  6414100192  2014-12-09 00:00:00+00:00  538000       3.0       2.25
# 2  5631500400  2015-02-25 00:00:00+00:00  180000       2.0       1.00
# 3  2487200875  2014-12-09 00:00:00+00:00  604000       4.0       3.00
# 4  1954400510  2015-02-18 00:00:00+00:00  510000       3.0       2.00
#
#    sqft_living  sqft_lot  floors  waterfront  view     ...      grade  \
# 0         1180      5650     1.0           0     0     ...          7
# 1         2570      7242     2.0           0     0     ...          7
# 2          770     10000     1.0           0     0     ...          6
# 3         1960      5000     1.0           0     0     ...          7
# 4         1680      8080     1.0           0     0     ...          8
#
#    sqft_above  sqft_basement  yr_built  yr_renovated  zipcode        lat  \
# 0        1180              0      1955             0  98178.0  47.511234
# 1        2170            400      1951          1991  98125.0  47.721023
# 2         770              0      1933             0  98028.0  47.737927
# 3        1050            910      1965             0  98136.0  47.520820
# 4        1680              0      1987             0  98074.0  47.616812
#
#          long  sqft_living15  sqft_lot15
# 0 -122.256775         1340.0      5650.0
# 1 -122.318862         1690.0      7639.0
# 2 -122.233196         2720.0      8062.0
# 3 -122.393185         1360.0      5000.0
# 4 -122.044901         1800.0      7503.0
#
# [5 rows x 21 columns]

# %%
print df.dtypes
print df.describe()
# Out:
# id                object
# date              object
# price              int64
# bedrooms          object
# bathrooms         object
# sqft_living        int64
# sqft_lot           int64
# floors            object
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode           object
# lat              float64
# long             float64
# sqft_living15    float64
# sqft_lot15       float64
# dtype: object
#             price  sqft_living    sqft_lot  waterfront      view  condition  \
# count   21613.000    21613.000   21613.000   21613.000 21613.000  21613.000
# mean   540088.142     2079.900   15106.968       0.008     0.234      3.409
# std    367127.196      918.441   41420.512       0.087     0.766      0.651
# min     75000.000      290.000     520.000       0.000     0.000      1.000
# 25%    321950.000     1427.000    5040.000       0.000     0.000      3.000
# 50%    450000.000     1910.000    7618.000       0.000     0.000      3.000
# 75%    645000.000     2550.000   10688.000       0.000     0.000      4.000
# max   7700000.000    13540.000 1651359.000       1.000     4.000      5.000
#
#           grade  sqft_above  sqft_basement  yr_built  yr_renovated       lat  \
# count 21613.000   21613.000      21613.000 21613.000     21613.000 21613.000
# mean      7.657    1788.391        291.509  1971.005        84.402    47.560
# std       1.175     828.091        442.575    29.373       401.679     0.139
# min       1.000     290.000          0.000  1900.000         0.000    47.156
# 25%       7.000    1190.000          0.000  1951.000         0.000    47.471
# 50%       7.000    1560.000          0.000  1975.000         0.000    47.572
# 75%       8.000    2210.000        560.000  1997.000         0.000    47.678
# max      13.000    9410.000       4820.000  2015.000      2015.000    47.778
#
#            long  sqft_living15  sqft_lot15
# count 21613.000      21613.000   21613.000
# mean   -122.214       1986.552   12768.456
# std       0.141        685.391   27304.180
# min    -122.519        399.000     651.000
# 25%    -122.328       1490.000    5100.000
# 50%    -122.230       1840.000    7620.000
# 75%    -122.125       2360.000   10083.000
# max    -121.315       6210.000  871200.000

# %% [markdown]
# ### Exploring the data for house sales

# %%
from matplotlib import pyplot as plt

plt.scatter(df.sqft_living, df.price, s=[1 for i in xrange(len(df.sqft_living))])
plt.xlabel("sqft_living")
plt.ylabel("price")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Build regression model

# %%
from sklearn.linear_model import LinearRegression
import logging
from sklearn.model_selection import train_test_split
import numpy as np

def rmse(clf, data):
    "Calculates RSS on classifier and data"
    return np.sqrt(np.mean((data.price - clf.predict(data.drop("price", axis=1)))**2))

def build_model(df):
    
    #Split on train/test data
    train_data, test_data = train_test_split(df, train_size=.8, random_state=0)
    
    print test_data.price.mean()
    
    clf = LinearRegression()
    clf.fit(train_data.drop("price", axis=1), train_data.price)
    
    print train_data.head()
    
    print "RSS on test data", rmse(clf, test_data)
    print "RSS on train data", rmse(clf, train_data)
    print clf.score(test_data.drop("price", axis=1), test_data.price)
    return clf, train_data, test_data

clf, train_data, test_data = build_model(df[["sqft_living", "price"]])
# Out:
# 529242.610687
#        sqft_living   price
# 5268          1570  495000
# 16909         1780  635000
# 16123         1090  382500
# 12181         2210  382500
# 12617         1800  670000
# RSS on test data 248879.061436
# RSS on train data 264522.963772
# 0.479157707997

# %% [markdown]
# * RMSE = $\sqrt{\sum{\frac{(y_i - \hat{y_i})^2}{n}}}$ where $\hat{y_i}$ is predicted value and $y_i$ is real value

# %% [markdown]
# Plot results

# %%
plt.scatter(train_data.sqft_living, train_data.price, color="blue", s=[1 for i in xrange(len(train_data))])
plt.scatter(test_data.sqft_living, test_data.price, color="green", s=[1 for i in xrange(len(test_data))])
plt.plot(df.sqft_living, clf.predict(df[["sqft_living"]]), color="red")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Get coefficients

# %%
print "Intercept={}, sqft_living={}".format(
    clf.intercept_, clf.coef_
)
# Out:
# Intercept=-48257.0634556, sqft_living=[ 283.96855737]

# %% [markdown]
# # Explore other features of the data

# %%
myFeatures = ['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'zipcode', 'price']
df_lite = df[myFeatures]

#don't display e+ notation
pd.set_option('display.float_format', lambda x: '%.3f' % x)

df_lite.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors   zipcode   price
# 0     3.000      1.000         1180      5650   1.000 98178.000  221900
# 1     3.000      2.250         2570      7242   2.000 98125.000  538000
# 2     2.000      1.000          770     10000   1.000 98028.000  180000
# 3     4.000      3.000         1960      5000   1.000 98136.000  604000
# 4     3.000      2.000         1680      8080   1.000 98074.000  510000

# %%
#Box plot

df_lite[df_lite.zipcode.isin(df_lite.zipcode.value_counts().index[:100])
       ].boxplot(column="price", by="zipcode", rot=90)
# Out:
# <img src="data:image/png;base64,..." width="936">

# %% [markdown]
# ### Build a regression model with more features

# %%
clfMany, train_data, test_data = build_model(df_lite)
# Out:
# 529242.610687
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  zipcode   price
# 5268      3.000      1.000         1570      5510   1.000    98115  495000
# 16909     3.000      2.500         1780     11000   1.000    98006  635000
# 16123     3.000      1.500         1090      9862   1.000    98074  382500
# 12181     4.000      2.500         2210      7079   2.000    98031  382500
# 12617     3.000      2.500         1800      4763   2.000    98119  670000
# RSS on test data 244004.774431
# RSS on train data 258524.684848

# %% [markdown]
# ### Apply learned models

# %%
h1 = df[df.id=="5309101200"][myFeatures]

print "H1 real price: {}, predicted by one feature: {}, predicted by several features: {}".format(
    h1.price.values[0], 
    clf.predict(h1[["sqft_living"]])[0], 
    clfMany.predict(h1.drop("price", axis=1))[0]
)
# Out:
# H1 real price: 620000, predicted by one feature: 633267.474227, predicted by several features: 637556.265159
